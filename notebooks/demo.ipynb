# %%
# Add relevant Jupyter notebook extensions

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['C:\\Program Files\\Python\\Python313\\python313.zip', 'C:\\Program Files\\Python\\Python313\\DLLs', 'C:\\Program Files\\Python\\Python313\\Lib', 'C:\\Program Files\\Python\\Python313', 'c:\\Users\\DX\\Documents\\Python\\UNI_WORK\\Scientific_Compute\\dev_env', '', 'c:\\Users\\DX\\Documents\\Python\\UNI_WORK\\Scientific_Compute\\dev_env\\Lib\\site-packages', 'c:\\Users\\DX\\Documents\\Python\\UNI_WORK\\Scientific_Compute\\dev_env\\Lib\\site-packages\\win32', 'c:\\Users\\DX\\Documents\\Python\\UNI_WORK\\Scientific_Compute\\dev_env\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\DX\\Documents\\Python\\UNI_WORK\\Scientific_Compute\\dev_env\\Lib\\site-packages\\Pythonwin']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules
import os
import sys
sys.path.append(os.path.abspath('..'))

from uuv_mission.dynamic import Submarine, ClosedLoop, Mission
from uuv_mission.control import PDController

project_root = os.path.abspath('..') # prevents os.path from changing over repeat runthroughs
mission_file_path = os.path.join(project_root, 'data', 'mission.csv')

sub = Submarine()
# Instantiate your controller (depending on your implementation)
controller = PDController(KP=0.15, KD=0.6)
closed_loop = ClosedLoop(sub, controller)
mission = Mission.from_csv(mission_file_path) # You must implement this method in the Mission class

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
